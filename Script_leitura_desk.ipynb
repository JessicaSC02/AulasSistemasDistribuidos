# %%
import dask.dataframe as dd
from dask.distributed import Client

# %%
df = dd.read_csv('dados.csv')
print(df.head())
# Out:
#    id  valor
# 0   1      1
# 1   2      2
# 2   3      3
# 3   4      4
# 4   5      5

# %%
resultado = df['valor'].sum().compute()
print(resultado)
# Out:
# 50000005000000

# %%
client=Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:62259' processes=4 threads=12, memory=31.84 GiB>
